# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Ingest Raw Data
#
# **Objective:** In this notebook, you will write a utility function to ingest data from a remote source.

# %% [markdown]
# ## Configuration
#
# Run the following cell to configure the notebook environment.

# %%
# %run ./includes/configuration
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %whos function
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Variable             Type        Data/Info
# ------------------------------------------
# retrieve_data        function    &lt;function retrieve_data at 0x7f546f150d30&gt;
# stop_all_streams     function    &lt;function stop_all_streams at 0x7f546f150c10&gt;
# stop_named_stream    function    &lt;function stop_named_stream at 0x7f546f150b80&gt;
# udf                  function    &lt;function udf at 0x7f54777ccca0&gt;
# untilStreamIsReady   function    &lt;function untilStreamIsReady at 0x7f546f150af0&gt;
# urlretrieve          function    &lt;function urlretrieve at 0x7f5477d0b700&gt;
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Reset Project

# %%
dbutils.fs.rm(health_tracker, recurse=True)

spark.sql(
    f"""
DROP TABLE IF EXISTS health_tracker_processed
"""
)

spark.sql(
    f"""
DROP TABLE IF EXISTS health_tracker_gold_aggregate_heartrate
"""
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: DataFrame[]</div>

# %% [markdown]
# ## Retrieve First Month of Data
#
# Next, we use the utility function, `retrieve_data` to
# retrieve the files we will ingest. The function takes
# three arguments:
#
# - `year: int`
# - `month: int`
# - `rawPath: str`
# - `is_late: bool` (optional)

# %%
retrieve_data(2020, 1, health_tracker + "raw/")
retrieve_data(2020, 2, health_tracker + "raw/")
retrieve_data(2020, 2, health_tracker + "raw/", is_late=True)
retrieve_data(2020, 3, health_tracker + "raw/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %% [markdown]
# ### Expected File
#
# The expected file has the following name:

# %%
file_2020_1 = "health_tracker_data_2020_1.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Display the Files in the Raw Path

# %%
display(dbutils.fs.ls(health_tracker + "raw/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/shalonn/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_1.json</td><td>health_tracker_data_2020_1.json</td><td>310628</td></tr><tr><td>dbfs:/dbacademy/shalonn/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_2.json</td><td>health_tracker_data_2020_2.json</td><td>284670</td></tr><tr><td>dbfs:/dbacademy/shalonn/lakehouse-with-delta-lake-dd/health-tracker/raw/health_tracker_data_2020_3.json</td><td>health_tracker_data_2020_3.json</td><td>402785</td></tr><tr><td>dbfs:/dbacademy/shalonn/lakehouse-with-delta-lake-dd/health-tracker/raw/late/</td><td>late/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# **Exercise:** Write an Assertion Statement to Verify File Ingestion
#
# Note: the `print` statement would typically not be included in production code, nor in code used to test this notebook.

# %%
# TODO
assert file_2020_1 in [item.name for item in dbutils.fs.ls(health_tracker + "raw/")], "File not present in Raw Path"
print("Assertion passed.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Assertion passed.
# </div>

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
